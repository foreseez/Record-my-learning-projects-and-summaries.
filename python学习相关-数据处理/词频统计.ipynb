# %%
import string
import time

path='freq.txt'

with open(path,'r') as text:
    words=[raw_word.strip(string.punctuation).lower() for raw_word in text.read().split()]
    words_index=set(words)
    counts_dict={index:words.count(index) for index in words_index}
for word in sorted(counts_dict,key=lambda x:counts_dict[x],reverse=True):
    time.sleep(2)
    print ('{}--{} times'.format(word,counts_dict[word]))
# Out:
# the--75 times
# knowledge--55 times
# of--45 times
# a--41 times
# graph--35 times
# in--35 times
# and--32 times
# as--23 times
# to--20 times
# are--20 times
# graphs--19 times
# refinement--17 times
# is--17 times
# for--15 times
# or--14 times
# methods--14 times
# such--12 times
# which--11 times
# we--10 times
# by--9 times
# survey--9 times
# this--9 times
# with--8 times
# not--8 times
# be--8 times
# that--8 times
# from--8 times
# it--7 times
# those--7 times
# construction--7 times
# web--7 times
# relations--7 times
# entities--7 times
# can--6 times
# approaches--6 times
# well--5 times
# i.e--5 times
# semantic--5 times
# data--5 times
# section--5 times
# on--5 times
# proposed--5 times
# there--4 times
# focus--4 times
# have--4 times
# level--4 times
# use--4 times
# their--4 times
# refining--4 times
# information--4 times
# different--4 times
# various--4 times
# applied--4 times
# many--3 times
# learning--3 times
# been--3 times
# representation--3 times
# other--3 times
# what--3 times
# would--3 times
# description--3 times
# given--3 times
# only--3 times
# characteristics--3 times
# concept--3 times
# differ--3 times
# completion--3 times
# operations--3 times
# types--3 times
# has--3 times
# schema--3 times
# one--3 times
# dimensions--3 times
# missing--3 times
# evaluation--3 times
# try--3 times
# create--3 times
# 2--3 times
# statements--3 times
# more--3 times
# considered--3 times
# both--3 times
# ontology--3 times
# datasets--3 times
# works--3 times
# correctness--3 times
# means--3 times
# used--3 times
# --2 times
# allows--2 times
# increasing--2 times
# yago--2 times
# identifying--2 times
# hamlet--2 times
# since--2 times
# present--2 times
# could--2 times
# detection--2 times
# coverage--2 times
# improve--2 times
# adding--2 times
# e.g--2 times
# mainly--2 times
# number--2 times
# dbpedia--2 times
# while--2 times
# linked--2 times
# arbitrary--2 times
# methodologies--2 times
# google--2 times
# logic--2 times
# they--2 times
# further--2 times
# included--2 times
# between--2 times
# coined--2 times
# organized--2 times
# however--2 times
# but--2 times
# about--2 times
# 2012--2 times
# above--2 times
# few--2 times
# interrelations--2 times
# –--2 times
# any--2 times
# also--2 times
# increase--2 times
# graph-based--2 times
# sources--2 times
# article--2 times
# perspective--2 times
# removing--2 times
# definition--2 times
# thus--2 times
# rdf--2 times
# completeness--2 times
# consider--2 times
# error--2 times
# at--2 times
# goals--2 times
# some--2 times
# shakespeare--2 times
# term--2 times
# classes--2 times
# set--2 times
# possible--2 times
# approach--2 times
# cases--2 times
# rather--2 times
# two--2 times
# a-box--2 times
# was--2 times
# contrast--2 times
# defines--2 times
# all--2 times
# being--2 times
# quality--2 times
# ontologies--1 times
# method--1 times
# values--1 times
# must--1 times
# collection--1 times
# effectiveness--1 times
# available--1 times
# organizations--1 times
# inconsistent--1 times
# statistical--1 times
# orthogonal--1 times
# t-box--1 times
# principle--1 times
# creating--1 times
# among--1 times
# large--1 times
# interlinked--1 times
# deals--1 times
# relate--1 times
# interlinking--1 times
# summarizes--1 times
# provide--1 times
# table--1 times
# topical--1 times
# post--1 times
# likewise--1 times
# nodes--1 times
# denoted--1 times
# using--1 times
# date--1 times
# refer--1 times
# pieces--1 times
# advantages--1 times
# created--1 times
# logical--1 times
# refined--1 times
# research--1 times
# initial--1 times
# often--1 times
# 8--1 times
# graphbased--1 times
# cleaner--1 times
# connected--1 times
# ones--1 times
# understanding--1 times
# harvested--1 times
# differences--1 times
# density--1 times
# review--1 times
# global--1 times
# freebase--1 times
# dataset--1 times
# consistency--1 times
# hierarchy--1 times
# cities--1 times
# rights--1 times
# heterogenous--1 times
# effects--1 times
# outside--1 times
# along--1 times
# decoupling--1 times
# identify--1 times
# view--1 times
# connectivity--1 times
# similar--1 times
# restrict--1 times
# advent--1 times
# referring--1 times
# already--1 times
# discussed--1 times
# if--1 times
# prominent--1 times
# commercial--1 times
# processing--1 times
# 7--1 times
# fields--1 times
# large-scale--1 times
# much--1 times
# early--1 times
# vs--1 times
# real--1 times
# free-of-error--1 times
# directly--1 times
# include--1 times
# openly--1 times
# order--1 times
# distinguish--1 times
# step--1 times
# result--1 times
# stated--1 times
# 5--1 times
# gives--1 times
# descriptions--1 times
# isolation--1 times
# separation--1 times
# 1--1 times
# connecting--1 times
# first--1 times
# years--1 times
# combination--1 times
# describes--1 times
# common--1 times
# impact--1 times
# goal--1 times
# nature--1 times
# qualified--1 times
# world--1 times
# collections--1 times
# its--1 times
# places--1 times
# understood--1 times
# broader--1 times
# authors--1 times
# entities.with--1 times
# degree--1 times
# very--1 times
# former--1 times
# press--1 times
# main--1 times
# generic--1 times
# introduction--1 times
# better--1 times
# formal--1 times
# then--1 times
# majority--1 times
# trade-off--1 times
# measures--1 times
# average--1 times
# external--1 times
# related--1 times
# interrelating--1 times
# things--1 times
# search--1 times
# add--1 times
# semi-structured--1 times
# good--1 times
# wrong--1 times
# concerned--1 times
# ourselves--1 times
# kind--1 times
# follows--1 times
# attempting--1 times
# open--1 times
# sets--1 times
# work--1 times
# observed--1 times
# errors--1 times
# least--1 times
# days--1 times
# correction--1 times
# three--1 times
# potentially--1 times
# categorization--1 times
# automatic--1 times
# these--1 times
# critical--1 times
# graphs.2--1 times
# assumes--1 times
# same--1 times
# brief--1 times
# basic--1 times
# node--1 times
# fine-tuning--1 times
# conclude--1 times
# scratch--1 times
# developing--1 times
# free--1 times
# concluded--1 times
# interlink--1 times
# latter--1 times
# 4--1 times
# roughly--1 times
# wikipedia--1 times
# identical--1 times
# infer--1 times
# into--1 times
# reserved--1 times
# communities--1 times
# multiple--1 times
# 3--1 times
# semanticweb--1 times
# promoted--1 times
# domains--1 times
# may--1 times
# steps--1 times
# developed--1 times
# size--1 times
# look--1 times
# utility--1 times
# so--1 times
# usually--1 times
# second--1 times
# restrictions--1 times
# make--1 times
# linguistic--1 times
# publishing--1 times
# recent--1 times
# strings--1 times
# schema.allows--1 times
# domain--1 times
# rest--1 times
# reflection--1 times
# tell--1 times
# minimum--1 times
# 6--1 times
# existing--1 times
# an--1 times
# entity--1 times
# most--1 times
# other.covers--1 times
# notion--1 times
# cloud--1 times
# evaluating--1 times
# links--1 times
# address--1 times
# recently--1 times
# writer--1 times
# ultimately--1 times
# heuristics--1 times
# standard3--1 times
# erroneous--1 times
# play--1 times
# itself--1 times
# larger--1 times
# structured--1 times
# pushing--1 times
# instead--1 times
# than--1 times
# summary--1 times
# written--1 times
# important--1 times
# improved--1 times
# bases--1 times
# validating--1 times
# take--1 times
# shortcomings--1 times
# dual--1 times
# before--1 times
# after--1 times
# note--1 times
# 1,000--1 times
# graph,mainly--1 times
# reviewed--1 times
# when--1 times
# example--1 times
# base--1 times
# following--1 times
# researchers--1 times
# constructed--1 times
# findings--1 times
# target--1 times
# survey.there--1 times
# reasoning--1 times
# instance--1 times
# although--1 times
# no--1 times
# literal--1 times
# each--1 times
# training--1 times
# edges--1 times
